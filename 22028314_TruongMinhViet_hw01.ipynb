# %% [markdown]
# Try editing it so that this sentence is the last sentence in the paragraph, and then click the 'run cell' ▶ button or hold down shift + return

# %%
print("First this line,")
print("then the whole 🌏,")
print("and then this one.")
# Out:
# First this line,
# then the whole 🌏,
# and then this one.

# %%
print("A whole new cell! ♪🌏♪")
# Out:
# A whole new cell! ♪🌏♪

# %%
eleven + 8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-45c6a336eedf> in <cell line: 0>()
# ----> 1 eleven + 8
#
# NameError: name 'eleven' is not defined

# %%
close_to_pi = 355/113
close_to_pi
# Out:
# 3.1415929203539825

# %%
semimonthly_salary = 843 + 1/3  # 843.33
monthly_salary = 2 * semimonthly_salary
number_of_months_in_a_year = 12
yearly_salary = number_of_months_in_a_year * monthly_salary
yearly_salary
# Out:
# 20240.0

# %%
a = 842.5
b = 2 * a
c = 12
d = c * b
d
# Out:
# 20220.0

# %%
# Change the next line
# so that it computes the number of seconds in a decade
# and assigns that number the name, seconds_in_a_decade.

seconds_in_a_decade = ((8 * 365) + (2 * 366))* 86400

# We've put this line in this cell
# so that it will print the value you've given to seconds_in_a_decade when you run it.
# You don't need to change this.
seconds_in_a_decade
# Out:
# 315532800

# %%
time = 1.2
estimated_distance_m = 1.13

# %%
gravity_constant = 6.674 * 10**-11

moon_mass_kg = 7.34767309 * 10**22

moon_radius_m = 1.737 * 10**6

predicted_distance_m = 0.5 * (gravity_constant * moon_mass_kg / moon_radius_m**2) * time**2

difference = predicted_distance_m - estimated_distance_m

difference
# Out:
# 0.040223694659304865

# %%
num_streets_away = abs(42 - 34)

num_avenues_away = abs(7 - 10)

street_length_m = 80
avenue_length_m = 274

manhattan_distance = street_length_m * num_streets_away + avenue_length_m * num_avenues_away

manhattan_distance
# Out:
# 1462

# %%
genghis_distance_from_average_in = abs(16.7-18.2)

genghis_distance_from_average_in
# Out:
# 1.5

# %%
hummus =  24.5
gatkes = 19.7
zeepty = 15.8

min_length_difference = min(abs(hummus - gatkes),
abs(hummus - zeepty),
abs(gatkes - zeepty))
min_length_difference
# Out:
# 3.8999999999999986
